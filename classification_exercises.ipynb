# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from pydataset import data
import acquire
import os
from scipy import stats

# %%
# get iris data

df_iris = data('iris')

# %%
# print first three rows

print(df_iris.head(3))
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa

# %%
# print the number of rows and columns

print(df_iris.shape)
# Out:
# (150, 5)

# %%
# print the column names

print(list(df_iris.columns))
# Out:
# ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width', 'Species']

# %%
# print the data type of each column

print(df_iris.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 1 to 150
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal.Length  150 non-null    float64
#  1   Sepal.Width   150 non-null    float64
#  2   Petal.Length  150 non-null    float64
#  3   Petal.Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 7.0+ KB
# None

# %%
# print the summary statistics for each of the numeric variables

print(df_iris.describe())

# Would you recommend rescaling the data based on these statistics?
# all measurements are in cm, if range was larger then scaling may be appropriate
# Out:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df_train = pd.read_csv('/Users/robcasey/Desktop/train.csv')

# %%
# print the first 3 rows

df_train.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
# print the number of rows and columns

print(df_train.shape)
# Out:
# (891, 12)

# %%
# print the column names

print(list(df_train.columns))
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
# print the data type of each column

df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# print the summary statistics for each of the numeric variables

print(df_train.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# print the unique values for each of your categorical variables

print(df_train.nunique())
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %% [markdown]
# Read the downloaded file into a dataframe named df_excel.
#
# assign the first 100 rows to a new dataframe, df_excel_sample
# print the number of rows of your original dataframe
# print the first 5 column names
# print the column names that have a data type of object
# compute the range for each of the numeric variables.

# %%
# Read the downloaded file into a dataframe named df_excel

sheet_url = 'https://docs.google.com/spreadsheets/d/1Uhtml8KY19LILuZsrDtlsHHDC9wuDGUSe8LTEwvdI5g/edit#gid=341089357'

csv_export_url = sheet_url.replace('/edit#gid=', '/export?format=csv&gid=')

df_excel = pd.read_csv(csv_export_url)

# %%
# assign the first 100 rows to a new dataframe, df_excel_sample

df_excel_sample = df_excel.head(99)

# %%
# print the number of rows of your original dataframe

print(df_excel.shape)
# Out:
# (891, 12)

# %%
# print the first 5 column names

print(df_excel.columns[:5])
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex'], dtype='object')

# %%
df_excel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# print the column names that have a data type of object

object_columns = df_excel.select_dtypes(include = ['object']).columns
object_columns
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
# compute the range for each of the numeric variables.

numeric_columns = df_excel.select_dtypes(include=['int64', 'float64']).columns
numeric_columns

# compute the range for each numeric column
excel_ranges = {}
for col in numeric_columns:
    excel_ranges[col] = df_excel[col].max() - df_excel[col].min()

# print the range for each numeric column
for col, r in excel_ranges.items():
    print(f"{col} range: {r}")
# Out:
# PassengerId range: 890
# Survived range: 1
# Pclass range: 2
# Age range: 79.58
# SibSp range: 8
# Parch range: 6
# Fare range: 512.3292

# %%
iris_df = acquire.get_iris_data()

# %%
iris_df.head()
# Out:
#    species_id species_name  measurement_id  sepal_length  sepal_width  \
# 0           1       setosa               1           5.1          3.5
# 1           1       setosa               2           4.9          3.0
# 2           1       setosa               3           4.7          3.2
# 3           1       setosa               4           4.6          3.1
# 4           1       setosa               5           5.0          3.6
#
#    petal_length  petal_width
# 0           1.4          0.2
# 1           1.4          0.2
# 2           1.3          0.2
# 3           1.5          0.2
# 4           1.4          0.2

# %%
telco_df = acquire.get_telco_data()

# %%
telco_df.head()
# Out:
#    payment_type_id  internet_service_type_id  contract_type_id customer_id  \
# 0                2                         1                 2  0002-ORFBO
# 1                2                         1                 1  0003-MKNFE
# 2                1                         2                 1  0004-TLHLJ
# 3                1                         2                 1  0011-IGKFF
# 4                2                         2                 1  0013-EXCHZ
#
#    gender  senior_citizen partner dependents  tenure phone_service  ...  \
# 0  Female               0     Yes        Yes       9           Yes  ...
# 1    Male               0      No         No       9           Yes  ...
# 2    Male               0      No         No       4           Yes  ...
# 3    Male               1     Yes         No      13           Yes  ...
# 4  Female               1     Yes         No       3           Yes  ...
#
#   tech_support streaming_tv streaming_movies paperless_billing  \
# ...

# %%
titanic_df = acquire.get_titanic_data()
titanic_df.head()
# Out:
# Reading from cached file.
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class deck  embark_town  alone
# 0        S  Third  NaN  Southampton      0
# 1        C  First    C    Cherbourg      0
# 2        S  Third  NaN  Southampton      1
# 3        S  First    C  Southampton      0
# 4        S  Third  NaN  Southampton      1

# %% [markdown]
# ## Preparation

# %% [markdown]
# Using the Iris Data:
#
# Use the function defined in acquire.py to load the iris data.
#
# Drop the species_id and measurement_id columns.
#
# Rename the species_name column to just species.
#
# Create dummy variables of the species name and concatenate onto the iris dataframe. (This is for practice, we don't always have to encode the target, but if we used species as a feature, we would need to encode it).
#
# Create a function named prep_iris that accepts the untransformed iris data, and returns the data with the transformations above applied.

# %% [markdown]
# ## Iris

# %%
import acquire as acq
iris_df = acq.get_iris_data()
iris_df.head()
# Out:
#    species_id species_name  measurement_id  sepal_length  sepal_width  \
# 0           1       setosa               1           5.1          3.5
# 1           1       setosa               2           4.9          3.0
# 2           1       setosa               3           4.7          3.2
# 3           1       setosa               4           4.6          3.1
# 4           1       setosa               5           5.0          3.6
#
#    petal_length  petal_width
# 0           1.4          0.2
# 1           1.4          0.2
# 2           1.3          0.2
# 3           1.5          0.2
# 4           1.4          0.2

# %%
# review - since species is the thing being predicted, species_id isnt needed.
#        - When talking about a target, it may or may not need to be encoded.
#        - Depending on the type.

iris_df.drop(['species_id'], axis=1, inplace=True)
iris_df.head()
# Out:
#   species_name  measurement_id  sepal_length  sepal_width  petal_length  \
# 0       setosa               1           5.1          3.5           1.4
# 1       setosa               2           4.9          3.0           1.4
# 2       setosa               3           4.7          3.2           1.3
# 3       setosa               4           4.6          3.1           1.5
# 4       setosa               5           5.0          3.6           1.4
#
#    petal_width
# 0          0.2
# 1          0.2
# 2          0.2
# 3          0.2
# 4          0.2

# %%
iris_df.rename(columns={'species_name':'species'}, inplace=True)
iris_df.head()
# Out:
#   species  measurement_id  sepal_length  sepal_width  petal_length  \
# 0  setosa               1           5.1          3.5           1.4
# 1  setosa               2           4.9          3.0           1.4
# 2  setosa               3           4.7          3.2           1.3
# 3  setosa               4           4.6          3.1           1.5
# 4  setosa               5           5.0          3.6           1.4
#
#    petal_width
# 0          0.2
# 1          0.2
# 2          0.2
# 3          0.2
# 4          0.2

# %%
iris_df.drop(['measurement_id'], axis=1, inplace=True)

# %%
iris_dummy = pd.get_dummies(iris_df[['species']], drop_first=False)
iris_dummy.head()
# Out:
#    species_setosa  species_versicolor  species_virginica
# 0               1                   0                  0
# 1               1                   0                  0
# 2               1                   0                  0
# 3               1                   0                  0
# 4               1                   0                  0

# %% [markdown]
# Note: one-hot encoding not the best for target variable. Sometimes they need encoding, but we would generally need to keep them in a single series.

# %%
new_iris_df = pd.concat([iris_df, iris_dummy], axis=1)
new_iris_df.head()
# Out:
#   species  sepal_length  sepal_width  petal_length  petal_width  \
# 0  setosa           5.1          3.5           1.4          0.2
# 1  setosa           4.9          3.0           1.4          0.2
# 2  setosa           4.7          3.2           1.3          0.2
# 3  setosa           4.6          3.1           1.5          0.2
# 4  setosa           5.0          3.6           1.4          0.2
#
#    species_setosa  species_versicolor  species_virginica
# 0               1                   0                  0
# 1               1                   0                  0
# 2               1                   0                  0
# 3               1                   0                  0
# 4               1                   0                  0

# %%
## review. 
# pd.concat([iris.]
#          pd.)

## review pd.crosstab(iris.species_id, iris.species_name)

# %%
def prep_iris(df):
    # args: iris, a single pandas dataframe
    # return: a cleaned single iris dataframe
    
    # Use the function defined in acquire.py to load the iris data
    import acquire as acq
    iris_df = acq.get_iris_data()
    
    # Drop the species_id and measurement_id columns
    iris_df.drop(['species_id'], axis=1, inplace=True)
    iris_df.drop(['measurement_id'], axis=1, inplace=True)
    
    # Rename the species_name column to just species
    iris_df.rename(columns={'species_name':'species'}, inplace=True)
    
    # Create dummy variables of the species name.
    iris_dummy = pd.get_dummies(iris_df[['species']], drop_first=False)
    new_iris = pd.concat([iris_df, iris_dummy], axis=1)
    
    return new_iris

# %%
iris = acq.get_iris_data()
iris = prep_iris(iris)
iris.head()
# Out:
#   species  sepal_length  sepal_width  petal_length  petal_width  \
# 0  setosa           5.1          3.5           1.4          0.2
# 1  setosa           4.9          3.0           1.4          0.2
# 2  setosa           4.7          3.2           1.3          0.2
# 3  setosa           4.6          3.1           1.5          0.2
# 4  setosa           5.0          3.6           1.4          0.2
#
#    species_setosa  species_versicolor  species_virginica
# 0               1                   0                  0
# 1               1                   0                  0
# 2               1                   0                  0
# 3               1                   0                  0
# 4               1                   0                  0

# %% [markdown]
# ## Titanic

# %% [markdown]
# Use the function defined in acquire.py to load the Titanic data.
#
# Drop any unnecessary, unhelpful, or duplicated columns.
#
# Encode the categorical columns. Create dummy variables of the categorical columns and concatenate them onto the dataframe.
#
# Create a function named prep_titanic that accepts the raw titanic data, and returns the data with the transformations above applied.

# %% [markdown]
# from sklearn. impute import simpleimputer
# sklearn 101 process
#
# want to use this with train set
#
# my_imputer = simpleimputer
#
# # make the thing
# titanic_df
# simpleimputer(strategy='mean')
#
# # fit the thing
# fit computes the mean inside of titanic's age and stores that value in the object
# simpleimputer.fit(titanic[['age']])
#
# # use the thing
# transform will use that stored fit value to make any fills to our missing data
# simpleimputer.transform(titanic[['age']])

# %%
titanic_df = acq.get_titanic_data()
titanic_df.head()
# Out:
# Reading from cached file.
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class deck  embark_town  alone
# 0        S  Third  NaN  Southampton      0
# 1        C  First    C    Cherbourg      0
# 2        S  Third  NaN  Southampton      1
# 3        S  First    C  Southampton      0
# 4        S  Third  NaN  Southampton      1

# %%
titanic_df.isnull().sum()
# Out:
# passenger_id      0
# survived          0
# pclass            0
# sex               0
# age             177
# sibsp             0
# parch             0
# fare              0
# embarked          2
# class             0
# deck            688
# embark_town       2
# alone             0
# dtype: int64

# %%
titanic_not_null = titanic_df[titanic_df.embark_town.notnull()]
titanic_not_null.isnull().sum()
# Out:
# passenger_id      0
# survived          0
# pclass            0
# sex               0
# age             177
# sibsp             0
# parch             0
# fare              0
# embarked          0
# class             0
# deck            688
# embark_town       0
# alone             0
# dtype: int64

# %%
titanic_not_null.drop(columns='deck', inplace=True)
titanic_not_null.head()
# Out:
# /var/folders/rb/x6d_9hp10qjb7n9jjvj0_jrm0000gn/T/ipykernel_23222/4017152815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic_not_null.drop(columns='deck', inplace=True)
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class  embark_town  alone
# 0        S  Third  Southampton      0
# 1        C  First    Cherbourg      0
# 2        S  Third  Southampton      1
# ...

# %%
titanic_dummy = pd.get_dummies(titanic_not_null[['embarked']], drop_first=False)
new_titanic = pd.concat([titanic_not_null, titanic_dummy], axis=1)

new_titanic.head()
# Out:
#    passenger_id  survived  pclass     sex   age  sibsp  parch     fare  \
# 0             0         0       3    male  22.0      1      0   7.2500
# 1             1         1       1  female  38.0      1      0  71.2833
# 2             2         1       3  female  26.0      0      0   7.9250
# 3             3         1       1  female  35.0      1      0  53.1000
# 4             4         0       3    male  35.0      0      0   8.0500
#
#   embarked  class  embark_town  alone  embarked_C  embarked_Q  embarked_S
# 0        S  Third  Southampton      0           0           0           1
# 1        C  First    Cherbourg      0           1           0           0
# 2        S  Third  Southampton      1           0           0           1
# 3        S  First  Southampton      0           0           0           1
# 4        S  Third  Southampton      1           0           0           1

# %%
list(new_titanic.columns)
# Out:
# ['passenger_id',
#  'survived',
#  'pclass',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'fare',
#  'embarked',
#  'class',
#  'embark_town',
#  'alone',
#  'embarked_C',
#  'embarked_Q',
#  'embarked_S']

# %%
from sklearn.model_selection import train_test_split

train_validate, test = train_test_split(new_titanic, test_size=.2,
                                       random_state=123,
                                       stratify=new_titanic.survived)
train_validate.shape, test.shape
# Out:
# ((711, 15), (178, 15))

# %%
train, validate = train_test_split(train_validate, test_size=.3, 
                                   random_state=123, 
                                   stratify=train_validate.survived)
train.shape, validate.shape
# Out:
# ((497, 15), (214, 15))

# %%
import warnings
warnings.filterwarnings("ignore")

from sklearn.impute import SimpleImputer

my_strategy = 'mean'
column_list = ['age']

def impute(train, validate, test, my_strategy, column_list):
    imputer = SimpleImputer(strategy=my_strategy)
    train[column_list] = imputer.fit_transform(train[column_list])
    validate[column_list] = imputer.transform(validate[column_list])
    test[column_list] = imputer.transform(test[column_list])
    return train, validate, test

# %%
type(new_titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
import prepare as prep
prep.titanic_split()
# Out:
# Reading from cached file.
# (     passenger_id  survived  pclass     sex   age  sibsp  parch      fare  \
#  583           583         0       1    male  36.0      0      0   40.1250
#  165           165         1       3    male   9.0      0      2   20.5250
#  50             50         0       3    male   7.0      4      1   39.6875
#  259           259         1       2  female  50.0      0      1   26.0000
#  306           306         1       1  female   NaN      0      0  110.8833
#  ..            ...       ...     ...     ...   ...    ...    ...       ...
#  313           313         0       3    male  28.0      0      0    7.8958
#  636           636         0       3    male  32.0      0      0    7.9250
#  222           222         0       3    male  51.0      0      0    8.0500
#  485           485         0       3  female   NaN      3      1   25.4667
#  744           744         1       3    male  31.0      0      0    7.9250
#
# ...

# %%
titanic_train, titanic_validate, titanic_test = impute(train, validate, test, my_strategy, column_list)
titanic_train.info()
titanic_validate.info()
titanic_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 497 entries, 583 to 553
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   passenger_id  497 non-null    int64
#  1   survived      497 non-null    int64
#  2   pclass        497 non-null    int64
#  3   sex           497 non-null    object
#  4   age           497 non-null    float64
#  5   sibsp         497 non-null    int64
#  6   parch         497 non-null    int64
#  7   fare          497 non-null    float64
#  8   embarked      497 non-null    object
#  9   class         497 non-null    object
#  10  embark_town   497 non-null    object
#  11  alone         497 non-null    int64
#  12  embarked_C    497 non-null    uint8
#  13  embarked_Q    497 non-null    uint8
#  14  embarked_S    497 non-null    uint8
# dtypes: float64(2), int64(6), object(4), uint8(3)
# memory usage: 51.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# ## Telco

# %%
telco_df.head().T
# Out:
#                                      0               1                 2  \
# payment_type_id                      2               2                 1
# internet_service_type_id             1               1                 2
# contract_type_id                     2               1                 1
# customer_id                 0002-ORFBO      0003-MKNFE        0004-TLHLJ
# gender                          Female            Male              Male
# senior_citizen                       0               0                 0
# partner                            Yes              No                No
# dependents                         Yes              No                No
# tenure                               9               9                 4
# phone_service                      Yes             Yes               Yes
# multiple_lines                      No             Yes                No
# online_security                     No              No                No
# ...

# %%
telco_df.shape
# Out:
# (7043, 24)

# %%
telco_df.drop_duplicates(inplace=True)

# %%
telco_df.shape
# Out:
# (7043, 24)

# %%
drop_columns = ['payment_type_id', 'internet_service_type_id', \
               'contract_type_id', 'customer_id']

# %%
telco_df.drop(columns=drop_columns, inplace=True)

# %%
telco_df.head().T
# Out:
#                                   0               1                 2  \
# gender                       Female            Male              Male
# senior_citizen                    0               0                 0
# partner                         Yes              No                No
# dependents                      Yes              No                No
# tenure                            9               9                 4
# phone_service                   Yes             Yes               Yes
# multiple_lines                   No             Yes                No
# online_security                  No              No                No
# online_backup                   Yes              No                No
# device_protection                No              No               Yes
# tech_support                    Yes              No                No
# streaming_tv                    Yes              No                No
# ...

# %%
# list columns
catcol = [col for col in telco_df.columns if telco_df[col].dtype == 'O']

# %%
catcol
# Out:
# ['gender',
#  'partner',
#  'dependents',
#  'phone_service',
#  'multiple_lines',
#  'online_security',
#  'online_backup',
#  'device_protection',
#  'tech_support',
#  'streaming_tv',
#  'streaming_movies',
#  'paperless_billing',
#  'total_charges',
#  'churn',
#  'contract_type',
#  'internet_service_type',
#  'payment_type']

# %%
# Encode Categorical Columns

dummy_df = pd.get_dummies(telco_df[catcol], dummy_na=False, drop_first=[True, True])
dummy_df
# Out:
#       gender_Male  partner_Yes  dependents_Yes  phone_service_Yes  \
# 0               0            1               1                  1
# 1               1            0               0                  1
# 2               1            0               0                  1
# 3               1            1               0                  1
# 4               0            1               0                  1
# ...           ...          ...             ...                ...
# 7038            0            0               0                  1
# 7039            1            1               0                  1
# 7040            1            0               0                  1
# 7041            1            1               1                  1
# 7042            1            1               1                  0
#
#       multiple_lines_No phone service  multiple_lines_Yes  \
# 0                                   0                   0
# ...

# %%
telco_df = pd.concat([telco_df, dummy_df], axis=1)
telco_df.head()
# Out:
#    gender  senior_citizen partner dependents  tenure phone_service  \
# 0  Female               0     Yes        Yes       9           Yes
# 1    Male               0      No         No       9           Yes
# 2    Male               0      No         No       4           Yes
# 3    Male               1     Yes         No      13           Yes
# 4  Female               1     Yes         No       3           Yes
#
#   multiple_lines online_security online_backup device_protection  ...  \
# 0             No              No           Yes                No  ...
# 1            Yes              No            No                No  ...
# 2             No              No            No               Yes  ...
# 3             No              No           Yes               Yes  ...
# 4             No              No            No                No  ...
#
#   total_charges_999.8 total_charges_999.9 churn_Yes contract_type_One year  \
# ...

# %%
telco_df.shape
# Out:
# (7043, 6577)

# %%
prep.prep_telco(acquire.get_telco_data())
# Out:
#       gender  senior_citizen partner dependents  tenure phone_service  \
# 0     Female               0     Yes        Yes       9           Yes
# 1       Male               0      No         No       9           Yes
# 2       Male               0      No         No       4           Yes
# 3       Male               1     Yes         No      13           Yes
# 4     Female               1     Yes         No       3           Yes
# ...      ...             ...     ...        ...     ...           ...
# 7038  Female               0      No         No      13           Yes
# 7039    Male               0     Yes         No      22           Yes
# 7040    Male               0      No         No       2           Yes
# 7041    Male               0     Yes        Yes      67           Yes
# 7042    Male               0     Yes        Yes      63            No
#
#         multiple_lines online_security online_backup device_protection  ...  \
# ...

# %% [markdown]
# Return and Review

# %% [markdown]
# # Split the data
# 1. Write a function to split the data into train, validate and test datasets.
# 2. Add this function into prepare.py

# %%
telco_prepared = prep.prep_telco(acquire.get_telco_data())
telco_prepared.head().T
# Out:
#                                                   0               1  \
# gender                                       Female            Male
# senior_citizen                                    0               0
# partner                                         Yes              No
# dependents                                      Yes              No
# tenure                                            9               9
# phone_service                                   Yes             Yes
# multiple_lines                                   No             Yes
# online_security                                  No              No
# online_backup                                   Yes              No
# device_protection                                No              No
# tech_support                                    Yes              No
# streaming_tv                                    Yes              No
# streaming_movies                                 No             Yes
# ...

# %% [markdown]
# # Exploration
# 1. Use the iris dataset. Split data into train, test and validate samples.

# %%
from sklearn.model_selection import train_test_split

# %%
train_validate, test = train_test_split(iris, test_size=.2,
                                       random_state=123,
                                       stratify=iris.species)
train_validate.shape, test.shape
# Out:
# ((120, 8), (30, 8))

# %%
train, validate = train_test_split(train_validate, test_size=.3, 
                                   random_state=123, 
                                   stratify=train_validate.species)
train.shape, validate.shape
# Out:
# ((84, 8), (36, 8))

# %%
iris_train = train
iris_validate = validate
iris_test = test

# %%
iris_train.info()
iris_validate.info()
iris_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 84 entries, 79 to 73
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   species             84 non-null     object
#  1   sepal_length        84 non-null     float64
#  2   sepal_width         84 non-null     float64
#  3   petal_length        84 non-null     float64
#  4   petal_width         84 non-null     float64
#  5   species_setosa      84 non-null     uint8
#  6   species_versicolor  84 non-null     uint8
#  7   species_virginica   84 non-null     uint8
# dtypes: float64(4), object(1), uint8(3)
# memory usage: 4.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 134 to 124
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   species             36 non-null     object
#  1   sepal_length        36 non-null     float64
# ...

# %% [markdown]
# # Univeriate
#
# For each measurement type (quantitative variable):
#
# create a histogram,
#
# boxplot, & compute descriptive statistics (using .describe()).

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   species             150 non-null    object
#  1   sepal_length        150 non-null    float64
#  2   sepal_width         150 non-null    float64
#  3   petal_length        150 non-null    float64
#  4   petal_width         150 non-null    float64
#  5   species_setosa      150 non-null    uint8
#  6   species_versicolor  150 non-null    uint8
#  7   species_virginica   150 non-null    uint8
# dtypes: float64(4), object(1), uint8(3)
# memory usage: 6.4+ KB

# %%
num_vars = ['sepal_length','sepal_width','petal_length', 'petal_width']
cat_vars = ['species']

# %%
# for loop -> numerical variables making boxplots

for col in num_vars:
    print(col)
    print(iris_train[col].describe())
    iris_train[col].hist()
    plt.show()
    sns.boxplot(y=col, data=iris_train)
    plt.show()
# Out:
# sepal_length
# count    84.000000
# mean      5.870238
# std       0.769099
# min       4.400000
# 25%       5.375000
# 50%       5.800000
# 75%       6.400000
# max       7.900000
# Name: sepal_length, dtype: float64
# sepal_width
# count    84.000000
# mean      3.075000
# std       0.448256
# min       2.200000
# 25%       2.800000
# 50%       3.000000
# 75%       3.400000
# max       4.400000
# Name: sepal_width, dtype: float64
# petal_length
# count    84.000000
# mean      3.771429
# std       1.734940
# min       1.200000
# 25%       1.600000
# 50%       4.250000
# 75%       5.100000
# max       6.900000
# Name: petal_length, dtype: float64
# petal_width
# count    84.000000
# mean      1.203571
# std       0.752577
# min       0.100000
# 25%       0.400000
# 50%       1.300000
# 75%       1.800000
# max       2.500000
# Name: petal_width, dtype: float64

# %%
# for loop -> categorical variable

for col in cat_vars:
    print(col)
    print(iris_train[col].value_counts())
    print(iris_train[col].value_counts(normalize=True)*100)
    sns.countplot(x=col, data=iris_train)
    plt.show()
# Out:
# species
# versicolor    28
# setosa        28
# virginica     28
# Name: species, dtype: int64
# versicolor    33.333333
# setosa        33.333333
# virginica     33.333333
# Name: species, dtype: float64

# %% [markdown]
# # Bivariate
#
# Visualize each measurement type (y-axis) with the species variable (x-axis)
#
# using barplots, adding a horizontal line showing the overall mean of the metric (y-axis).

# %%
# for loop - bar plot for numerical variables + dotted mean indicators

for col in num_vars:
    sns.barplot(x='species', y=col, data=iris_train)
    species_rate = iris_train[col].mean()
    plt.axhline(species_rate,  label = f'Overall Mean of {col}', linestyle='dotted', color='black')
    plt.legend()
    plt.show()

# %% [markdown]
# For each measurement type, compute the descriptive statistics for each species.

# %%
iris_train.groupby('species').describe().T
# Out:
# species                      setosa  versicolor  virginica
# sepal_length       count  28.000000   28.000000  28.000000
#                    mean    5.089286    5.896429   6.625000
#                    std     0.360390    0.425556   0.532378
#                    min     4.400000    4.900000   5.800000
#                    25%     4.875000    5.600000   6.300000
#                    50%     5.000000    5.800000   6.450000
#                    75%     5.400000    6.125000   6.900000
#                    max     5.800000    6.900000   7.900000
# sepal_width        count  28.000000   28.000000  28.000000
#                    mean    3.467857    2.796429   2.960714
#                    std     0.427788    0.280848   0.318956
#                    min     2.300000    2.300000   2.200000
#                    25%     3.275000    2.600000   2.800000
#                    50%     3.400000    2.800000   3.000000
#                    75%     3.800000    3.000000   3.100000
# ...

# %% [markdown]
# For virginica & versicolor: Compare the mean petal_width using the Mann-Whitney test
#
# (scipy.stats.mannwhitneyu) to see if there is a significant difference between the two
#
# groups. Do the same for the other measurement types.

# %%
virginica = iris_train[iris_train.species=='virginica']
versicolor = iris_train[iris_train.species=='versicolor']

# %%
virginica
# Out:
#        species  sepal_length  sepal_width  petal_length  petal_width  \
# 133  virginica           6.3          2.8           5.1          1.5
# 139  virginica           6.9          3.1           5.4          2.1
# 115  virginica           6.4          3.2           5.3          2.3
# 145  virginica           6.7          3.0           5.2          2.3
# 125  virginica           7.2          3.2           6.0          1.8
# 126  virginica           6.2          2.8           4.8          1.8
# 142  virginica           5.8          2.7           5.1          1.9
# 131  virginica           7.9          3.8           6.4          2.0
# 128  virginica           6.4          2.8           5.6          2.1
# 129  virginica           7.2          3.0           5.8          1.6
# 103  virginica           6.3          2.9           5.6          1.8
# 123  virginica           6.3          2.7           4.9          1.8
# 120  virginica           6.9          3.2           5.7          2.3
# ...

# %%
stats.mannwhitneyu(virginica['petal_width'], 
                   versicolor['petal_width'], 
                   alternative='two-sided')
# Out:
# MannwhitneyuResult(statistic=767.0, pvalue=6.47119166980993e-10)

# %%
test_var = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
test_var
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']

# %%
# for loop to test variables against mannwhitneyu

for var in test_var:
    t, p = t, p = stats.mannwhitneyu(virginica[var], versicolor[var], alternative="greater")
    print(f'Comparing {var} between virginica and versicolor')
    print(t, p)
    print('------------------')
    print('\n')
# Out:
# Comparing sepal_length between virginica and versicolor
# 676.5 1.541014598267054e-06
# ------------------
#
#
# Comparing sepal_width between virginica and versicolor
# 510.0 0.02628629569922847
# ------------------
#
#
# Comparing petal_length between virginica and versicolor
# 776.5 1.4739917857575313e-10
# ------------------
#
#
# Comparing petal_width between virginica and versicolor
# 767.0 3.235595834904965e-10
# ------------------

# %% [markdown]
# # Multivariate
# Visualize the interaction of each measurement type with the others using a pairplot (or scatter matrix or something similar) and add color to represent species.

# %%
sns.pairplot(data = iris_train, hue='species', corner=True);

# %% [markdown]
# Visualize two numeric variables of the species. Hint: sns.relplot with hue or col

# %%
sns.relplot(data=iris_train, x='petal_length', y='petal_width', hue='species')
plt.show()

# %% [markdown]
# Create a swarmplot using a melted dataframe of all your numeric variables.
#
# The x-axis should be the variable name, the y-axis is the measure.
#
# Add another dimension using color to represent species.
#
# Document takeaways from this visualization.

# %%
# melted dataframe
iris_train_melt = iris_train.melt(id_vars='species', var_name='feature', value_name='measurement')

#swarmplot
plt.figure(figsize=(13, 7))
sns.swarmplot(data=iris_train_melt, x = 'feature', y = 'measurement', hue = 'species')

plt.show()

# %%
# alternative answer

sns.swarmplot(data=iris_train, x='species', y='sepal_length')
plt.show()

# %%
train_melt = iris_train.melt(id_vars = 'species')
train_melt.head()
# Out:
#       species      variable  value
# 0  versicolor  sepal_length    5.7
# 1      setosa  sepal_length    5.5
# 2   virginica  sepal_length    6.3
# 3  versicolor  sepal_length    5.7
# 4      setosa  sepal_length    5.7

# %%
sns.swarmplot(data=train_melt, x='variable', y='value', hue='species')
plt.show()

# %%
iris_train.corr()
# Out:
#                     sepal_length  sepal_width  petal_length  petal_width  \
# sepal_length            1.000000    -0.154904      0.867976     0.824691
# sepal_width            -0.154904     1.000000     -0.476228    -0.403306
# petal_length            0.867976    -0.476228      1.000000     0.957345
# petal_width             0.824691    -0.403306      0.957345     1.000000
# species_setosa         -0.722317     0.623439     -0.928394    -0.877707
# species_versicolor      0.024224    -0.442075      0.205008     0.104650
# species_virginica       0.698093    -0.181364      0.723386     0.773058
#
#                     species_setosa  species_versicolor  species_virginica
# sepal_length             -0.722317            0.024224           0.698093
# sepal_width               0.623439           -0.442075          -0.181364
# petal_length             -0.928394            0.205008           0.723386
# petal_width              -0.877707            0.104650           0.773058
# ...

# %%
sns.heatmap(iris_train.corr(), 
            cmap='mako', center=0, annot=True)
plt.show()

# %% [markdown]
# # Part II

# %% [markdown]
# Explore the titanic data more completely
#
# - Determine drivers of the target variable
# - Determine if certain columns should be dropped
# - Determine if it would be valuable to bin some numeric columns
# - Determine if it would be valuable to combine multiple columns into one.
